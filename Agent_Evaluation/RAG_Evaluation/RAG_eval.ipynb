# %% [markdown]
# ### Running RAG Based Agent Evaluation

# %%
# %pip install openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openai in /home/yair/.local/lib/python3.10/site-packages (1.66.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/yair/.local/lib/python3.10/site-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/yair/.local/lib/python3.10/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/yair/.local/lib/python3.10/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/yair/.local/lib/python3.10/site-packages (from openai) (0.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/yair/.local/lib/python3.10/site-packages (from openai) (2.10.6)
# Requirement already satisfied: sniffio in /home/yair/.local/lib/python3.10/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/yair/.local/lib/python3.10/site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /home/yair/.local/lib/python3.10/site-packages (from openai) (4.12.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/yair/.local/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /home/yair/.local/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /home/yair/.local/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /home/yair/.local/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/yair/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/yair/.local/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/yair/.local/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (2.27.2)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install azure-ai-evaluation
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: azure-ai-evaluation in /home/yair/.local/lib/python3.10/site-packages (1.3.0)
# Requirement already satisfied: promptflow-devkit>=1.17.1 in /home/yair/.local/lib/python3.10/site-packages (from azure-ai-evaluation) (1.17.2)
# Requirement already satisfied: promptflow-core>=1.17.1 in /home/yair/.local/lib/python3.10/site-packages (from azure-ai-evaluation) (1.17.2)
# Requirement already satisfied: pyjwt>=2.8.0 in /home/yair/.local/lib/python3.10/site-packages (from azure-ai-evaluation) (2.10.1)
# Requirement already satisfied: azure-identity>=1.16.0 in /home/yair/.local/lib/python3.10/site-packages (from azure-ai-evaluation) (1.21.0)
# Requirement already satisfied: azure-core>=1.30.2 in /home/yair/.local/lib/python3.10/site-packages (from azure-ai-evaluation) (1.32.0)
# Requirement already satisfied: nltk>=3.9.1 in /home/yair/.local/lib/python3.10/site-packages (from azure-ai-evaluation) (3.9.1)
# Requirement already satisfied: azure-storage-blob>=12.10.0 in /home/yair/.local/lib/python3.10/site-packages (from azure-ai-evaluation) (12.25.0)
# Requirement already satisfied: requests>=2.21.0 in /home/yair/.local/lib/python3.10/site-packages (from azure-core>=1.30.2->azure-ai-evaluation) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in /home/yair/.local/lib/python3.10/site-packages (from azure-core>=1.30.2->azure-ai-evaluation) (1.17.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/yair/.local/lib/python3.10/site-packages (from azure-core>=1.30.2->azure-ai-evaluation) (4.12.2)
# Requirement already satisfied: cryptography>=2.5 in /home/yair/.local/lib/python3.10/site-packages (from azure-identity>=1.16.0->azure-ai-evaluation) (44.0.2)
# Requirement already satisfied: msal>=1.30.0 in /home/yair/.local/lib/python3.10/site-packages (from azure-identity>=1.16.0->azure-ai-evaluation) (1.32.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /home/yair/.local/lib/python3.10/site-packages (from azure-identity>=1.16.0->azure-ai-evaluation) (1.3.1)
# Requirement already satisfied: isodate>=0.6.1 in /home/yair/.local/lib/python3.10/site-packages (from azure-storage-blob>=12.10.0->azure-ai-evaluation) (0.7.2)
# Requirement already satisfied: click in /home/yair/.local/lib/python3.10/site-packages (from nltk>=3.9.1->azure-ai-evaluation) (8.1.8)
# Requirement already satisfied: joblib in /home/yair/.local/lib/python3.10/site-packages (from nltk>=3.9.1->azure-ai-evaluation) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/yair/.local/lib/python3.10/site-packages (from nltk>=3.9.1->azure-ai-evaluation) (2024.11.6)
# Requirement already satisfied: tqdm in /home/yair/.local/lib/python3.10/site-packages (from nltk>=3.9.1->azure-ai-evaluation) (4.67.1)
# Requirement already satisfied: docstring_parser in /home/yair/.local/lib/python3.10/site-packages (from promptflow-core>=1.17.1->azure-ai-evaluation) (0.16)
# Requirement already satisfied: fastapi<1.0.0,>=0.109.0 in /home/yair/.local/lib/python3.10/site-packages (from promptflow-core>=1.17.1->azure-ai-evaluation) (0.115.11)
# Requirement already satisfied: filetype>=1.2.0 in /home/yair/.local/lib/python3.10/site-packages (from promptflow-core>=1.17.1->azure-ai-evaluation) (1.2.0)
# Requirement already satisfied: flask<4.0.0,>=2.2.3 in /home/yair/.local/lib/python3.10/site-packages (from promptflow-core>=1.17.1->azure-ai-evaluation) (3.1.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /home/yair/.local/lib/python3.10/site-packages (from promptflow-core>=1.17.1->azure-ai-evaluation) (4.23.0)
# Requirement already satisfied: promptflow-tracing==1.17.2 in /home/yair/.local/lib/python3.10/site-packages (from promptflow-core>=1.17.1->azure-ai-evaluation) (1.17.2)
# Requirement already satisfied: psutil in /home/yair/.local/lib/python3.10/site-packages (from promptflow-core>=1.17.1->azure-ai-evaluation) (6.1.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1.0 in /home/yair/.local/lib/python3.10/site-packages (from promptflow-core>=1.17.1->azure-ai-evaluation) (2.9.0.post0)
# Requirement already satisfied: ruamel.yaml<1.0.0,>=0.17.10 in /home/yair/.local/lib/python3.10/site-packages (from promptflow-core>=1.17.1->azure-ai-evaluation) (0.18.10)
# Requirement already satisfied: openai in /home/yair/.local/lib/python3.10/site-packages (from promptflow-tracing==1.17.2->promptflow-core>=1.17.1->azure-ai-evaluation) (1.66.5)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.22.0 in /home/yair/.local/lib/python3.10/site-packages (from promptflow-tracing==1.17.2->promptflow-core>=1.17.1->azure-ai-evaluation) (1.31.0)
# Requirement already satisfied: tiktoken>=0.4.0 in /home/yair/.local/lib/python3.10/site-packages (from promptflow-tracing==1.17.2->promptflow-core>=1.17.1->azure-ai-evaluation) (0.9.0)
# Requirement already satisfied: argcomplete>=3.2.3 in /home/yair/.local/lib/python3.10/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (3.6.0)
# Requirement already satisfied: azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21 in /home/yair/.local/lib/python3.10/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (1.0.0b35)
# Requirement already satisfied: colorama<0.5.0,>=0.4.6 in /home/yair/.local/lib/python3.10/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (0.4.6)
# Requirement already satisfied: filelock<4.0.0,>=3.4.0 in /home/yair/.local/lib/python3.10/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (3.18.0)
# Requirement already satisfied: flask-cors<6.0.0,>=5.0.0 in /home/yair/.local/lib/python3.10/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (5.0.1)
# Requirement already satisfied: flask-restx<2.0.0,>=1.2.0 in /home/yair/.local/lib/python3.10/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (1.3.0)
# Requirement already satisfied: gitpython<4.0.0,>=3.1.24 in /home/yair/.local/lib/python3.10/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (3.1.44)
# Requirement already satisfied: httpx>=0.25.1 in /home/yair/.local/lib/python3.10/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (0.28.1)
# Requirement already satisfied: keyring<25.0.0,>=24.2.0 in /home/yair/.local/lib/python3.10/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (24.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.5 in /home/yair/.local/lib/python3.10/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (3.26.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0 in /home/yair/.local/lib/python3.10/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (1.31.0)
# Requirement already satisfied: pandas<3.0.0,>=1.5.3 in /home/yair/.local/lib/python3.10/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (2.2.3)
# Requirement already satisfied: pillow<11.1.0,>=10.1.0 in /home/yair/.local/lib/python3.10/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (11.0.0)
# Requirement already satisfied: pydash<8.0.0,>=6.0.0 in /home/yair/.local/lib/python3.10/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (7.0.7)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /home/yair/.local/lib/python3.10/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (1.0.1)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.48 in /home/yair/.local/lib/python3.10/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (2.0.39)
# Requirement already satisfied: strictyaml<2.0.0,>=1.5.0 in /home/yair/.local/lib/python3.10/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (1.7.3)
# Requirement already satisfied: tabulate<1.0.0,>=0.9.0 in /home/yair/.local/lib/python3.10/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (0.9.0)
# Requirement already satisfied: waitress<4.0.0,>=3.0.0 in /home/yair/.local/lib/python3.10/site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (3.0.2)
# Requirement already satisfied: fixedint==0.1.6 in /home/yair/.local/lib/python3.10/site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit>=1.17.1->azure-ai-evaluation) (0.1.6)
# Requirement already satisfied: msrest>=0.6.10 in /home/yair/.local/lib/python3.10/site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit>=1.17.1->azure-ai-evaluation) (0.7.1)
# Requirement already satisfied: opentelemetry-api~=1.26 in /home/yair/.local/lib/python3.10/site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit>=1.17.1->azure-ai-evaluation) (1.31.0)
# Requirement already satisfied: cffi>=1.12 in /home/yair/.local/lib/python3.10/site-packages (from cryptography>=2.5->azure-identity>=1.16.0->azure-ai-evaluation) (1.17.1)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /home/yair/.local/lib/python3.10/site-packages (from fastapi<1.0.0,>=0.109.0->promptflow-core>=1.17.1->azure-ai-evaluation) (0.46.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /home/yair/.local/lib/python3.10/site-packages (from fastapi<1.0.0,>=0.109.0->promptflow-core>=1.17.1->azure-ai-evaluation) (2.10.6)
# Requirement already satisfied: Werkzeug>=3.1 in /home/yair/.local/lib/python3.10/site-packages (from flask<4.0.0,>=2.2.3->promptflow-core>=1.17.1->azure-ai-evaluation) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /home/yair/.local/lib/python3.10/site-packages (from flask<4.0.0,>=2.2.3->promptflow-core>=1.17.1->azure-ai-evaluation) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2 in /home/yair/.local/lib/python3.10/site-packages (from flask<4.0.0,>=2.2.3->promptflow-core>=1.17.1->azure-ai-evaluation) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in /home/yair/.local/lib/python3.10/site-packages (from flask<4.0.0,>=2.2.3->promptflow-core>=1.17.1->azure-ai-evaluation) (1.9.0)
# Requirement already satisfied: aniso8601>=0.82 in /home/yair/.local/lib/python3.10/site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit>=1.17.1->azure-ai-evaluation) (10.0.0)
# Requirement already satisfied: pytz in /home/yair/.local/lib/python3.10/site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit>=1.17.1->azure-ai-evaluation) (2025.1)
# Requirement already satisfied: importlib-resources in /home/yair/.local/lib/python3.10/site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit>=1.17.1->azure-ai-evaluation) (6.5.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/yair/.local/lib/python3.10/site-packages (from gitpython<4.0.0,>=3.1.24->promptflow-devkit>=1.17.1->azure-ai-evaluation) (4.0.12)
# Requirement already satisfied: anyio in /home/yair/.local/lib/python3.10/site-packages (from httpx>=0.25.1->promptflow-devkit>=1.17.1->azure-ai-evaluation) (4.9.0)
# Requirement already satisfied: certifi in /home/yair/.local/lib/python3.10/site-packages (from httpx>=0.25.1->promptflow-devkit>=1.17.1->azure-ai-evaluation) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /home/yair/.local/lib/python3.10/site-packages (from httpx>=0.25.1->promptflow-devkit>=1.17.1->azure-ai-evaluation) (1.0.7)
# Requirement already satisfied: idna in /home/yair/.local/lib/python3.10/site-packages (from httpx>=0.25.1->promptflow-devkit>=1.17.1->azure-ai-evaluation) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/yair/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.1->promptflow-devkit>=1.17.1->azure-ai-evaluation) (0.14.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/yair/.local/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core>=1.17.1->azure-ai-evaluation) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/yair/.local/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core>=1.17.1->azure-ai-evaluation) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/yair/.local/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core>=1.17.1->azure-ai-evaluation) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/yair/.local/lib/python3.10/site-packages (from jsonschema<5.0.0,>=4.0.0->promptflow-core>=1.17.1->azure-ai-evaluation) (0.23.1)
# Requirement already satisfied: jaraco.classes in /home/yair/.local/lib/python3.10/site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit>=1.17.1->azure-ai-evaluation) (3.4.0)
# Requirement already satisfied: importlib-metadata>=4.11.4 in /home/yair/.local/lib/python3.10/site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit>=1.17.1->azure-ai-evaluation) (8.6.1)
# Requirement already satisfied: SecretStorage>=3.2 in /usr/lib/python3/dist-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit>=1.17.1->azure-ai-evaluation) (3.3.1)
# Requirement already satisfied: jeepney>=0.4.2 in /usr/lib/python3/dist-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit>=1.17.1->azure-ai-evaluation) (0.7.1)
# Requirement already satisfied: packaging>=17.0 in /home/yair/.local/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.5->promptflow-devkit>=1.17.1->azure-ai-evaluation) (24.2)
# Requirement already satisfied: deprecated>=1.2.6 in /home/yair/.local/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.17.1->azure-ai-evaluation) (1.2.18)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /home/yair/.local/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.17.1->azure-ai-evaluation) (1.69.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.31.0 in /home/yair/.local/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.17.1->azure-ai-evaluation) (1.31.0)
# Requirement already satisfied: opentelemetry-proto==1.31.0 in /home/yair/.local/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.17.1->azure-ai-evaluation) (1.31.0)
# Requirement already satisfied: protobuf<6.0,>=5.0 in /home/yair/.local/lib/python3.10/site-packages (from opentelemetry-proto==1.31.0->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.17.1->azure-ai-evaluation) (5.29.3)
# Requirement already satisfied: numpy>=1.22.4 in /home/yair/.local/lib/python3.10/site-packages (from pandas<3.0.0,>=1.5.3->promptflow-devkit>=1.17.1->azure-ai-evaluation) (2.2.4)
# Requirement already satisfied: tzdata>=2022.7 in /home/yair/.local/lib/python3.10/site-packages (from pandas<3.0.0,>=1.5.3->promptflow-devkit>=1.17.1->azure-ai-evaluation) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/yair/.local/lib/python3.10/site-packages (from requests>=2.21.0->azure-core>=1.30.2->azure-ai-evaluation) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/yair/.local/lib/python3.10/site-packages (from requests>=2.21.0->azure-core>=1.30.2->azure-ai-evaluation) (2.3.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /home/yair/.local/lib/python3.10/site-packages (from ruamel.yaml<1.0.0,>=0.17.10->promptflow-core>=1.17.1->azure-ai-evaluation) (0.2.12)
# Requirement already satisfied: greenlet!=0.4.17 in /home/yair/.local/lib/python3.10/site-packages (from sqlalchemy<3.0.0,>=1.4.48->promptflow-devkit>=1.17.1->azure-ai-evaluation) (3.1.1)
# Requirement already satisfied: pycparser in /home/yair/.local/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity>=1.16.0->azure-ai-evaluation) (2.22)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/yair/.local/lib/python3.10/site-packages (from deprecated>=1.2.6->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.17.1->azure-ai-evaluation) (1.17.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/yair/.local/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4.0.0,>=3.1.24->promptflow-devkit>=1.17.1->azure-ai-evaluation) (5.0.2)
# Requirement already satisfied: zipp>=3.20 in /home/yair/.local/lib/python3.10/site-packages (from importlib-metadata>=4.11.4->keyring<25.0.0,>=24.2.0->promptflow-devkit>=1.17.1->azure-ai-evaluation) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/yair/.local/lib/python3.10/site-packages (from Jinja2>=3.1.2->flask<4.0.0,>=2.2.3->promptflow-core>=1.17.1->azure-ai-evaluation) (3.0.2)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /home/yair/.local/lib/python3.10/site-packages (from msrest>=0.6.10->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit>=1.17.1->azure-ai-evaluation) (2.0.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.52b0 in /home/yair/.local/lib/python3.10/site-packages (from opentelemetry-sdk<2.0.0,>=1.22.0->promptflow-tracing==1.17.2->promptflow-core>=1.17.1->azure-ai-evaluation) (0.52b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/yair/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi<1.0.0,>=0.109.0->promptflow-core>=1.17.1->azure-ai-evaluation) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/yair/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi<1.0.0,>=0.109.0->promptflow-core>=1.17.1->azure-ai-evaluation) (2.27.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/yair/.local/lib/python3.10/site-packages (from anyio->httpx>=0.25.1->promptflow-devkit>=1.17.1->azure-ai-evaluation) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /home/yair/.local/lib/python3.10/site-packages (from anyio->httpx>=0.25.1->promptflow-devkit>=1.17.1->azure-ai-evaluation) (1.3.1)
# Requirement already satisfied: more-itertools in /home/yair/.local/lib/python3.10/site-packages (from jaraco.classes->keyring<25.0.0,>=24.2.0->promptflow-devkit>=1.17.1->azure-ai-evaluation) (10.6.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/yair/.local/lib/python3.10/site-packages (from openai->promptflow-tracing==1.17.2->promptflow-core>=1.17.1->azure-ai-evaluation) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/yair/.local/lib/python3.10/site-packages (from openai->promptflow-tracing==1.17.2->promptflow-core>=1.17.1->azure-ai-evaluation) (0.9.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/yair/.local/lib/python3.10/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.10->azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit>=1.17.1->azure-ai-evaluation) (3.2.2)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install azure-ai-projects==1.0.0b5
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: azure-ai-projects==1.0.0b5 in /home/yair/.local/lib/python3.10/site-packages (1.0.0b5)
# Requirement already satisfied: isodate>=0.6.1 in /home/yair/.local/lib/python3.10/site-packages (from azure-ai-projects==1.0.0b5) (0.7.2)
# Requirement already satisfied: azure-core>=1.30.0 in /home/yair/.local/lib/python3.10/site-packages (from azure-ai-projects==1.0.0b5) (1.32.0)
# Requirement already satisfied: typing-extensions>=4.12.2 in /home/yair/.local/lib/python3.10/site-packages (from azure-ai-projects==1.0.0b5) (4.12.2)
# Requirement already satisfied: requests>=2.21.0 in /home/yair/.local/lib/python3.10/site-packages (from azure-core>=1.30.0->azure-ai-projects==1.0.0b5) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in /home/yair/.local/lib/python3.10/site-packages (from azure-core>=1.30.0->azure-ai-projects==1.0.0b5) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/yair/.local/lib/python3.10/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-projects==1.0.0b5) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/yair/.local/lib/python3.10/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-projects==1.0.0b5) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/yair/.local/lib/python3.10/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-projects==1.0.0b5) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/yair/.local/lib/python3.10/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-projects==1.0.0b5) (2025.1.31)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Importing Libraries and Utilities

# %%
import os
from openai import AzureOpenAI
from dotenv import load_dotenv
from azure.identity import DefaultAzureCredential 
from azure.ai.projects import AIProjectClient

# %%
load_dotenv()
# [START create_project_client]
project_client = AIProjectClient.from_connection_string(
    credential=DefaultAzureCredential(),
    conn_str=os.getenv("PROJECT_CONNECTION_STRING")
)

model = os.getenv("AZURE_OPENAI_DEPLOYMENT")

# %% [markdown]
# #### Setting in the system prompt/instruction set for the QA Generator agent

# %%
system_prompt_1 = f"""You are meant to behave as an evaluation agent for azure ai agent evaluation.
The azure ai agent utilizes a RAG based approach to generate responses to user queries.
We need to evaluate the responses generated by the azure ai agent.
We will utilize the azure ai evaluation SDK for this purpose and specifically the Groundedness score which 
measures the extent to which the response is grounded in the context of the conversation.

The groundedness score tool takes in the following parameters:
query: The query that was used to generate the response.
context: The context that should be used/ or was used to generate the response.
response: The response that was generated by the model.

You will be passed a text document on top of which you need to generate one question that will help measure the groundedness of the response.

the output should strictly adhere to the following format:
<question>

Include only the question in the output and nothing else, not even filler words.
"""

# %% [markdown]
# #### Creating our QA Agent

# %%
QA_agent = project_client.agents.create_agent(  
        model="gpt-4",
        name="QA_generator",
        instructions=system_prompt_1,
    )
print(f"Created agent, agent ID: {QA_agent.id}")
QA_agent_id = QA_agent.id
# Out:
# Created agent, agent ID: asst_IhjNfFpSr5pMixmy4z98GwLg

# %% [markdown]
# #### Creating our Thread for the QA Agent

# %%
QA_thread = project_client.agents.create_thread()
print(f"Created thread, thread ID: {QA_thread.id}")

QA_thread_id = QA_thread.id
# Out:
# Created thread, thread ID: thread_LKAirNcFcnTvQgK1Kp0Zpl9k

# %%
eval_dict = []

# %% [markdown]
# #### Storing QA Response as a collection

# %%
for file in os.listdir("collateral"):
    with open(f"collateral/{file}", "r") as f:
        document_text= f.read()
        
        message = project_client.agents.create_message(
        thread_id=QA_thread_id,
        role="user",
        content=f"the document text is: {document_text} ",
        )
        
        run = project_client.agents.create_and_process_run(thread_id=QA_thread_id, agent_id=QA_agent_id)
        print(f"Run finished with status: {run.status}")
        
        messages = project_client.agents.list_messages(thread_id=QA_thread_id)
        #Displaying the assistant response
        print(messages.data[0].content[0].text.value)
        
        assistant_response = messages.data[0].content[0].text.value
        
        query_dict =  {"query": assistant_response,
                            "context": document_text
                         }
        
        
        
        eval_dict.append(query_dict)
        
print(eval_dict)
# Out:
# Run finished with status: failed
# the document text is: The City of New York, often called New York City or simply New York, is the most populous city in the United States. With an estimated 2015 population of 8,550,405 distributed over a land area of about 302.6 square miles, New York City is also the most densely populated major city in the United States. Located at the southern tip of the state of New York, the city is the center of the New York metropolitan area, one of the most populous urban agglomerations in the world. A global power city, New York City exerts a significant impact upon commerce, finance, media, art, fashion, research, technology, education, and entertainment, its fast pace defining the term New York minute. Home to the headquarters of the United Nations, New York is an important center for international diplomacy and has been described as the cultural and financial capital of the world.
# New York Hotels Margie’s Travel offers the following accommodation options in New York: The Manhattan Hotel Stay in the heart of New York City, within an easy walk to Times Square and Broadway. The Grand Central Hotel Comfortable mid-town hotel. Close to Grand Central Station, the Chrysler Building, and the Empire State Building. The Park Hotel Luxurious accommodation in upper Manhattan, with views of Central Park.
# Run finished with status: failed
# the document text is: Las Vegas, officially the City of Las Vegas and often known simply as Vegas, is the 28th-most populated city in the United States, the most populated city in the state of Nevada, and the county seat of Clark County. The city anchors the Las Vegas Valley metropolitan area and is the largest city within the greater Mojave Desert. Las Vegas is an internationally renowned major resort city, known primarily for its gambling, shopping, fine dining, entertainment, and nightlife. The Las Vegas Valley as a whole serves as the leading financial, commercial, and cultural center for Nevada.
# Las Vegas Hotels Margie’s Travel offers the following hotels in Las Vegas: The Volcano Hotel In the heart of The Strip. Stylish casino hotel with live entertainment and an extensive pool area. The Fountain Hotel Luxury accommodation in Las Vegas with a range of restaurants and cocktail bars The Canal Hotel An opulent Italian-themed resort with luxurious suite accommodation.
# Run finished with status: failed
# the document text is: Dubai is the largest and most populous city in the United Arab Emirates. It is located on the southeast coast of the Persian Gulf and is the capital of the Emirate of Dubai, one of the seven emirates that make up the country. Abu Dhabi and Dubai are the only two emirates to have veto power over critical matters of national importance in the country's Federal Supreme Council. The city of Dubai is located on the emirate's northern coastline and heads the Dubai-Sharjah-Ajman metropolitan area.
# Dubai Hotels Margie’s Travel offers the following accommodation options in Dubai: The Creek Hotel Friendly boutique hotel within the heart of the bustling Dubai Creek area. The Deira Hotel Family-run hotel in Dubai’s traditional commercial center. The Lost City Hotel Luxurious accommodation in Dubai, with onsite waterpark and aquarium.
# Run finished with status: failed
# the document text is: San Francisco, officially the City and County of San Francisco, is the cultural, commercial, and financial center of Northern California. It is the birthplace of the United Nations. Located at the north end of the San Francisco Peninsula, San Francisco is about 47.9 square miles in area, making it the smallest county—and the only consolidated city-county—within the state of California. With a density of about 18,581 people per square mile, San Francisco is the most densely settled large city in California and the second-most densely populated major city in the United States after New York City. San Francisco is the fourth-most populous city in California, after Los Angeles, San Diego, and San Jose, and the 13th-most populous city in the United States—with a census-estimated 2016 population of 870,887. The city and its surrounding areas are known as the San Francisco Bay Area, and are a part of the larger OMB-designated San Jose-San Francisco-Oakland combined statistical area, the fifth most populous in the nation with an estimated population of 8.7 million.
# San Francisco Hotels Margie’s Travel offers the following accommodation options in San Francisco: The Lombard Hotel Friendly, family-run hotel within easy walking distance to popular sights, including the Golden Gate Bridge and the Presidio. Free Parking. The Wharf Hotel Great value accommodation in the heart of the vibrant Fisherman’s Wharf area. Continental Breakfast included.
#
# Run finished with status: failed
# the document text is: London is the capital and most populous city of England and the United Kingdom. Standing on the River Thames in the south east of the island of Great Britain, London has been a major settlement for two millennia. It was founded by the Romans, who named it Londinium. London's ancient core, the City of London, largely retains its 1.12-square-mile medieval boundaries. Since at least the 19th century, London has also referred to the metropolis around this core, historically split between Middlesex, Essex, Surrey, Kent, and Hertfordshire, which today largely makes up Greater London, governed by the Mayor of London and the London Assembly.
# Mostly popular for:
# Leisure, Outdoors, Historical, Arts & Culture
# Best time to visit:
# Jun-Aug
# Averag Precipitation: 1.9 in
# Average Temperature: 56-67°F
# London Hotels Margie’s Travel offers the following accommodation options in London: The Buckingham Hotel Comfortable hotel close to major sights like Buckingham Palace, Regent’s Park, and Trafalgar Square. The City Hotel Luxury rooms in the city, within walking distance of Tower Bridge and the Tower of London.. The Kensington Hotel Budget accommodation near Earl’s Court.
# [{'query': 'the document text is: The City of New York, often called New York City or simply New York, is the most populous city in the United States. With an estimated 2015 population of 8,550,405 distributed over a land area of about 302.6 square miles, New York City is also the most densely populated major city in the United States. Located at the southern tip of the state of New York, the city is the center of the New York metropolitan area, one of the most populous urban agglomerations in the world. A global power city, New York City exerts a significant impact upon commerce, finance, media, art, fashion, research, technology, education, and entertainment, its fast pace defining the term New York minute. Home to the headquarters of the United Nations, New York is an important center for international diplomacy and has been described as the cultural and financial capital of the world.\nNew York Hotels Margie’s Travel offers the following accommodation options in New York: The Manhattan Hotel Stay in the heart of New York City, within an easy walk to Times Square and Broadway. The Grand Central Hotel Comfortable mid-town hotel. Close to Grand Central Station, the Chrysler Building, and the Empire State Building. The Park Hotel Luxurious accommodation in upper Manhattan, with views of Central Park. ', 'context': 'The City of New York, often called New York City or simply New York, is the most populous city in the United States. With an estimated 2015 population of 8,550,405 distributed over a land area of about 302.6 square miles, New York City is also the most densely populated major city in the United States. Located at the southern tip of the state of New York, the city is the center of the New York metropolitan area, one of the most populous urban agglomerations in the world. A global power city, New York City exerts a significant impact upon commerce, finance, media, art, fashion, research, technology, education, and entertainment, its fast pace defining the term New York minute. Home to the headquarters of the United Nations, New York is an important center for international diplomacy and has been described as the cultural and financial capital of the world.\nNew York Hotels Margie’s Travel offers the following accommodation options in New York: The Manhattan Hotel Stay in the heart of New York City, within an easy walk to Times Square and Broadway. The Grand Central Hotel Comfortable mid-town hotel. Close to Grand Central Station, the Chrysler Building, and the Empire State Building. The Park Hotel Luxurious accommodation in upper Manhattan, with views of Central Park.'}, {'query': 'the document text is: Las Vegas, officially the City of Las Vegas and often known simply as Vegas, is the 28th-most populated city in the United States, the most populated city in the state of Nevada, and the county seat of Clark County. The city anchors the Las Vegas Valley metropolitan area and is the largest city within the greater Mojave Desert. Las Vegas is an internationally renowned major resort city, known primarily for its gambling, shopping, fine dining, entertainment, and nightlife. The Las Vegas Valley as a whole serves as the leading financial, commercial, and cultural center for Nevada.\nLas Vegas Hotels Margie’s Travel offers the following hotels in Las Vegas: The Volcano Hotel In the heart of The Strip. Stylish casino hotel with live entertainment and an extensive pool area. The Fountain Hotel Luxury accommodation in Las Vegas with a range of restaurants and cocktail bars The Canal Hotel An opulent Italian-themed resort with luxurious suite accommodation. ', 'context': 'Las Vegas, officially the City of Las Vegas and often known simply as Vegas, is the 28th-most populated city in the United States, the most populated city in the state of Nevada, and the county seat of Clark County. The city anchors the Las Vegas Valley metropolitan area and is the largest city within the greater Mojave Desert. Las Vegas is an internationall ...

# %%
print(eval_dict[0]['query'])
#print(eval_dict[0]['context'])
# Out:
# the document text is: The City of New York, often called New York City or simply New York, is the most populous city in the United States. With an estimated 2015 population of 8,550,405 distributed over a land area of about 302.6 square miles, New York City is also the most densely populated major city in the United States. Located at the southern tip of the state of New York, the city is the center of the New York metropolitan area, one of the most populous urban agglomerations in the world. A global power city, New York City exerts a significant impact upon commerce, finance, media, art, fashion, research, technology, education, and entertainment, its fast pace defining the term New York minute. Home to the headquarters of the United Nations, New York is an important center for international diplomacy and has been described as the cultural and financial capital of the world.
# New York Hotels Margie’s Travel offers the following accommodation options in New York: The Manhattan Hotel Stay in the heart of New York City, within an easy walk to Times Square and Broadway. The Grand Central Hotel Comfortable mid-town hotel. Close to Grand Central Station, the Chrysler Building, and the Empire State Building. The Park Hotel Luxurious accommodation in upper Manhattan, with views of Central Park.

# %%
index_name=os.getenv("AI_SEARCH_INDEX_NAME")
print(index_name)
# Out:
# rag-1761514266317

# %%
from azure.ai.projects.models import AzureAISearchTool, ConnectionType

# %%
conn_list = project_client.connections.list()
conn_id = ""
for conn in conn_list:
    if conn.connection_type == ConnectionType.AZURE_AI_SEARCH:
        conn_id = conn.id
        break
print(conn_id)
# Out:
# /subscriptions/2ed78932-0b59-4288-9e59-7dabf0351177/resourceGroups/demo2_rg/providers/Microsoft.MachineLearningServices/workspaces/demo2-project/connections/ragdemoser

# %%
ai_search = AzureAISearchTool(index_connection_id=conn_id, index_name=index_name)

# %% [markdown]
# #### Creating our RAG Agent with Azure AI Search Index

# %%
RAG_agent = project_client.agents.create_agent(
        model=model,
        name="ai-search-assistant",
        instructions="You are a helpful assistant",
        tools=ai_search.definitions,
        tool_resources=ai_search.resources,
        headers={"x-ms-enable-preview": "true"},
    )
    # [END create_agent_with_azure_ai_search_tool]
print(f"Created agent, ID: {RAG_agent.id}")
# Out:
# Created agent, ID: asst_k21xQrdgSphSU5IApP04lK7n

# %%
RAG_thread = project_client.agents.create_thread()
print(f"Created thread, ID: {RAG_thread.id}")
# Out:
# Created thread, ID: thread_9WvCPr6HnVQ5Hq20uXT58XAc

# %% [markdown]
# #### Generating Response from the RAG Agent to fill in the "Response" Parameter

# %%
for eval_collection in eval_dict:
    query = eval_collection["query"]
    
    message = project_client.agents.create_message(
        thread_id=RAG_thread.id,
        role="user",
        content=f"answer this query{query}",
        )
    
    run = project_client.agents.create_and_process_run(thread_id=RAG_thread.id, agent_id=RAG_agent.id)
    print(f"Run finished with status: {run.status}")
        
    messages = project_client.agents.list_messages(thread_id=RAG_thread.id)
        #Displaying the assistant response
    print(messages.data[0].content[0].text.value)
        
    assistant_response = messages.data[0].content[0].text.value
    
    eval_collection["response"] = assistant_response
# Out:
# Run finished with status: completed
# What is your query regarding the provided text?
# Run finished with status: completed
# What specific query would you like answered based on the provided text?
# Run finished with status: completed
# Please provide your specific query so I can answer it based on the provided text.
# Run finished with status: completed
# What query would you like me to answer using the provided text?
# Run finished with status: completed
# Please provide your query regarding the provided text so I can address it accurately.

# %%
import json

# %%
with open('eval_dict.json', 'w') as f:
    json.dump(eval_dict, f, indent=4)

# %%
from azure.ai.evaluation import GroundednessEvaluator

# %%
azure_ai_project = {
    "subscription_id": os.getenv("AZURE_SUBSCRIPTION_ID"),
    "resource_group_name": os.getenv("AZURE_RESOURCE_GROUP"),
    "project_name": os.getenv("AZURE_PROJECT_NAME"),
}

model_config = {
    "azure_endpoint": os.getenv("AZURE_OPENAI_ENDPOINT"),
    "api_key": os.getenv("AZURE_OPENAI_API_KEY"),
    "azure_deployment": os.getenv("AZURE_OPENAI_DEPLOYMENT"),
    "api_version": os.getenv("AZURE_OPENAI_API_VERSION"),
}

# %%
credential = DefaultAzureCredential()
groundedness_eval = GroundednessEvaluator(model_config)

# %% [markdown]
# #### Evaluating the Groundness of the Response from the RAG Agent

# %%
for eval_collection in eval_dict:
    groundedness_score = groundedness_eval(
    **eval_collection
    )
    
    print(groundedness_score)
    
    json.dumps(groundedness_score)
    
    eval_collection['groundedness_score'] = groundedness_score['groundedness']
    eval_collection['groundedness_reason'] = groundedness_score['groundedness_reason']
# Out:
# [2025-10-27 19:54:07 +0200][promptflow.core._prompty_utils][ERROR] - Exception occurs: NotFoundError: Error code: 404 - {'error': {'code': '404', 'message': 'Resource not found'}}
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/promptflow/core/_prompty_utils.py:1191, in handle_openai_error_async.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#    1190 try:
# -> 1191     return await func(*args, **kwargs)
#    1192 except (SystemErrorException, UserErrorException) as e:
#    1193     # Throw inner wrapped exception directly
#
# File ~/.local/lib/python3.10/site-packages/promptflow/core/_flow.py:562, in AsyncPrompty.__call__(self, *args, **kwargs)
#     561 timeout = kwargs.get("timeout", None)
# --> 562 response = await send_request_to_llm(api_client, self._model.api, params, timeout)
#     563 return format_llm_response(
#     564     response=response,
#     565     api=self._model.api,
#    (...)
#     569     outputs=self._outputs,
#     570 )
#
# File ~/.local/lib/python3.10/site-packages/openai/resources/chat/completions/completions.py:2000, in AsyncCompletions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1999 validate_response_format(response_format)
# -> 2000 return await self._post(
#    2001     "/chat/completions",
#    2002     body=await async_maybe_transform(
#    2003         {
#    2004             "messages": messages,
#    2005             "model": model,
#    2006             "audio": audio,
#    2007             "frequency_penalty": frequency_penalty,
#    2008             "function_call": function_call,
#    2009             "functions": functions,
#    2010             "logit_bias": logit_bias,
#    2011             "logprobs": logprobs,
#    2012             "max_completion_tokens": max_completion_tokens,
#    2013             "max_tokens": max_tokens,
#    2014             "metadata": metadata,
#    2015             "modalities": modalities,
#    2016             "n": n,
#    2017             "parallel_tool_calls": parallel_tool_calls,
#    2018             "prediction": prediction,
#    2019             "presence_penalty": presence_penalty,
#    2020             "reasoning_effort": reasoning_effort,
#    2021             "response_format": response_format,
#    2022             "seed": seed,
#    2023             "service_tier": service_tier,
#    2024             "stop": stop,
#    2025             "store": store,
#    2026             "stream": stream,
#    2027             "stream_options": stream_options,
#    2028             "temperature": temperature,
#    2029             "tool_choice": tool_choice,
#    2030             "tools": tools,
#    2031             "top_logprobs": top_logprobs,
#    2032             "top_p": top_p,
#    2033             "user": user,
#    2034             "web_search_options": web_search_options,
#    2035         },
#    2036         completion_create_params.CompletionCreateParams,
#    2037     ),
#    2038     options=make_request_options(
#    2039         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    2040     ),
#    2041     cast_to=ChatCompletion,
#    2042     stream=stream or False,
#    2043     stream_cls=AsyncStream[ChatCompletionChunk],
#    2044 )
#
# File ~/.local/lib/python3.10/site-packages/openai/_base_client.py:1767, in AsyncAPIClient.post(self, path, cast_to, body, files, options, stream, stream_cls)
#    1764 opts = FinalRequestOptions.construct(
#    1765     method="post", url=path, json_data=body, files=await async_to_httpx_files(files), **options
#    1766 )
# -> 1767 return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File ~/.local/lib/python3.10/site-packages/openai/_base_client.py:1461, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1459     retries_taken = 0
# -> 1461 return await self._request(
#    1462     cast_to=cast_to,
#    1463     options=options,
#    1464     stream=stream,
#    1465     stream_cls=stream_cls,
#    1466     retries_taken=retries_taken,
#    1467 )
#
# File ~/.local/lib/python3.10/site-packages/openai/_base_client.py:1562, in AsyncAPIClient._request(self, cast_to, options, stream, stream_cls, retries_taken)
#    1561     log.debug("Re-raising status error")
# -> 1562     raise self._make_status_error_from_response(err.response) from None
#    1564 return await self._process_response(
#    1565     cast_to=cast_to,
#    1566     options=options,
#    (...)
#    1570     retries_taken=retries_taken,
#    1571 )
#
# NotFoundError: Error code: 404 - {'error': {'code': '404', 'message': 'Resource not found'}}
#
# During handling of the above exception, another exception occurred:
#
# WrappedOpenAIError                        Traceback (most recent call last)
# Cell In[54], line 2
#       1 for eval_collection in eval_dict:
# ----> 2     groundedness_score = groundedness_eval(
#       3     **eval_collection
#       4     )
#       6     print(groundedness_score)
#       8     json.dumps(groundedness_score)
#
# File ~/.local/lib/python3.10/site-packages/azure/ai/evaluation/_evaluators/_groundedness/_groundedness.py:144, in GroundednessEvaluator.__call__(self, *args, **kwargs)
#     137     prompty_model_config = construct_prompty_model_config(
#     138         validate_model_config(self._model_config),
#     139         self._DEFAULT_OPEN_API_VERSION,
#     140         USER_AGENT,
#     141     )
#     142     self._flow = AsyncPrompty.load(source=self._prompty_file, model=prompty_model_config)
# --> 144 return super().__call__(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/azure/ai/evaluation/_evaluators/_common/_base_eval.py:124, in EvaluatorBase.__call__(self, *args, **kwargs)
#     109 def __call__(  # pylint: disable=docstring-missing-param
#     110     self,
#     111     *args,
#     112     **kwargs,
#     113 ) -> Union[DoEvalResult[T_EvalValue], AggregateResult[T_EvalValue]]:
#     114     """Evaluate a given input. This method serves as a wrapper and is meant to be overridden by child classes for
#     115     one main reason - to overwrite the method headers and docstring to include additional inputs as needed.
#     116     The actual behavior of this function shouldn't change beyond adding more inputs to the
#    (...)
#     122     :rtype: Union[DoEvalResult[T_EvalValue], AggregateResult[T_EvalValue]]
#     123     """
# --> 124     return async_run_allowing_running_loop(self._async_evaluator, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/promptflow/_utils/async_utils.py:94, in async_run_allowing_running_loop(async_func, *args, **kwargs)
#      92 if _has_running_loop():
#      93     with ThreadPoolExecutorWithContext() as executor:
# ---> 94         return executor.submit(lambda: asyncio.run(async_func(*args, **kwargs))).result()
#      95 else:
#      96     return asyncio.run(_invoke_async_with_sigint_handler(async_func, *args, **kwargs))
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:458, in Future.result(self, timeout)
#     456     raise CancelledError()
#     457 elif self._state == FINISHED:
# --> 458     return self.__get_result()
#     459 else:
#     460     raise TimeoutError()
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File /usr/lib/python3.10/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~/.local/lib/python3.10/site-packages/promptflow/_utils/async_utils.py:94, in async_run_allowing_running_loop.<locals>.<lambda>()
#      92 if _has_running_loop():
#      93     with ThreadPoolExecutorWithContext() as executor:
# ---> 94         return executor.submit(lambda: asyncio.run(async_func(*args, **kwargs))).result()
#      95 else:
#      96     return asyncio.run(_invoke_async_with_sigint_handler(async_func, *args, **kwargs))
#
# File /usr/lib/python3.10/asyncio/runners.py:44, in run(main, debug)
#      42     if debug is not None:
#      43         loop.set_debug(debug)
# ---> 44     return loop.run_until_complete(main)
#      45 finally:
#      46     try:
#
# File /usr/lib/python3.10/asyncio/base_events.py:649, in BaseEventLoop.run_until_complete(self, future)
#     646 if not future.done():
#     647     raise RuntimeError('Event loop stopped before Future completed.')
# --> 649 return future.result()
#
# File ~/.local/lib/python3.10/site-packages/azure/ai/evaluation/_evaluators/_common/_base_eval.py:479, in AsyncEvaluatorBase.__call__(self, query, response, context, conversation, ground_truth, **kwargs)
#     477 if ground_truth is not None:
#     478     kwargs["ground_truth"] = ground_truth
# --> 479 return await self._real_call(**kwargs)
#
# File ~/.local/lib/python3.10/site-packages/azure/ai/evaluation/_evaluators/_common/_base_eval.py:396, in EvaluatorBase._real_call(self, **kwargs)
#     394 # Evaluate all inputs.
#     395 for eval_input in eval_input_list:
# --> 396     per_turn_results.append(await self._do_eval(eval_input))
#     397 # Return results as-is if only one result was produced.
#     399 if len(per_turn_results) == 1:
#
# File ~/.local/lib/python3.10/site-packages/azure/ai/evaluation/_evaluators/_common/_base_prompty_eval.py:83, in PromptyEvaluatorBase._do_eval(self, eval_input)
#      75 if "query" not in eval_input and "response" not in eval_input:
#      76     raise EvaluationException(
#      77         message="Only text conversation inputs are supported.",
#      78         internal_message="Only text conversation inputs are supported.",
#    (...)
#      81         target=ErrorTarget.CONVERSATION,
#      82     )
# ---> 83 llm_output = await self._flow(timeout=self._LLM_CALL_TIMEOUT, **eval_input)
#      85 score = math.nan
#      86 if llm_output:
#      87     # Parse out score and reason from evaluators known to possess them.
#
# File ~/.local/lib/python3.10/site-packages/promptflow/tracing/_trace.py:476, in _traced_async.<locals>.wrapped(*args, **kwargs)
#     473 from ._utils import is_tracing_disabled
#     475 if is_tracing_disabled():
# --> 476     return await func(*args, **kwargs)
#     478 trace = create_trace(func, args, kwargs)
#     479 # For node span we set the span name to node name, otherwise we use the function name.
#
# File ~/.local/lib/python3.10/site-packages/promptflow/core/_prompty_utils.py:1219, in handle_openai_error_async.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#    1217     status_code = e.response.status_code
#    1218     if status_code < 500 and status_code not in [429, 422]:
# -> 1219         raise WrappedOpenAIError(e)
#    1220 if isinstance(e, RateLimitError) and getattr(e, "type", None) == "insufficient_quota":
#    1221     # Exit retry if this is quota insufficient error
#    1222     logger.error(f"{type(e).__name__} with insufficient quota. Throw user error.")
#
# WrappedOpenAIError: OpenAI API hits NotFoundError: Error code: 404 - {'error': {'code': '404', 'message': 'Resource not found'}} [Error reference: https://platform.openai.com/docs/guides/error-codes/api-errors]

# %%
with open("eval_results.json", "w") as f:
    json.dump(eval_dict, f, indent=4)
